# %% [markdown]
# ## Домашнее задание №2
# ## Pandas

# %% [markdown]
# 1. Импортируйте пандас как pd и считайте файл TSLA.csv (https://www.kaggle.com/efekurdoglu/teslastockprice/data) как датафрейм

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/TSLA.csv');

# %% [markdown]
# 2. Удалите из столбца Close значения, целые части которых кратны 6

# %%
df.Close = df.Close.apply(lambda x: np.nan if x % 6 == 0 else x)
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020         NaN  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %% [markdown]
# 3. Теперь попробуйте заполнить пропуски средним значением в столбце, потом минимумом, потом медианой

# %%
df.fillna(df.mean()) #заполнение пропуском средним значением
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  186.212954  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
df.fillna(df.min()) #заполнение пропуском минимальным значением
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020   15.800000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
df.fillna(df.median) #заполнение пропуском медианным значением
# Out:
#             Date        Open        High         Low  \
# 0     2010-06-29   19.000000   25.000000   17.540001
# 1     2010-06-30   25.790001   30.420000   23.299999
# 2     2010-07-01   25.000000   25.920000   20.270000
# 3     2010-07-02   23.000000   23.100000   18.709999
# 4     2010-07-06   20.000000   20.000000   15.830000
# ...          ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017
# 2412  2020-01-29  575.690002  589.799988  567.429993
# 2413  2020-01-30  632.419983  650.880005  618.000000
# 2414  2020-01-31  640.000000  653.000000  632.520020
# 2415  2020-02-03  673.690002  786.140015  673.520020
#
#                                                   Close   Adj Close    Volume
# 0                                             23.889999   23.889999  18766300
# 1                                                 23.83   23.830000  17187100
# 2                                             21.959999   21.959999   8218800
# 3                                             19.200001   19.200001   5139800
# 4                                             16.110001   16.110001   6866900
# ...                                                 ...         ...       ...
# 2411                                         566.900024  566.900024  11788500
# 2412                                          580.98999  580.989990  17801500
# 2413                                         640.809998  640.809998  29005700
# 2414                                         650.570007  650.570007  15719300
# 2415  <bound method NDFrame._add_numeric_operations....  780.000000  47065000
#
# [2416 rows x 7 columns]

# %% [markdown]
# 4. А теперь попробуйте заполнить эти пропуски средним между всеми значениями, кратным 5 и всеми значениями, кратным 7 (т.е. выберите все значение, кратные 5 и найдите их среднее, а потом все значение, кратные 7, найдите среднее среди них, а потом усредните два полученных значения).

# %%
## df.loc[lambda x: x.Close % 5 == 0].mean().Close - среднее значение для кратных 5
## df.loc[lambda x: x.Close % 5 == 0].mean().Close - среднее значение для кратных 7

#среднее значение для кратных 5 и 7
meanDf = df.loc[lambda x: x.Close % 5 == 0].mean().Close + df.loc[lambda x: x.Close % 5 == 0].mean().Close / 2

df = df.fillna(meanDf) #заполнить и сохранить средним значением
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  352.500000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %% [markdown]
# 5. Импортируйте matplotlib.pyplot как plt. Постройте графики получишвихся наборов значений. Чтобы получше разглядеть, найдите как в pyplot задать размер графика и поставьте побольше.

# %%
from matplotlib.pyplot import figure

figure(figsize=(12,5), dpi=100)

df.Close.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 6. Приведите столбец High к строковому типу. Найдите все строки, где содержится цифра 9.
# Подсказка: загуглите pandas.str

# %%
df = df.High.astype("string")
df[(df.str.contains('9') == True)]
# Out:
# 2            25.92
# 5        16.629999
# 7             17.9
# 9        18.639999
# 12       21.299999
#            ...
# 2405    515.669983
# 2407         594.5
# 2409    573.859985
# 2411    576.809998
# 2412    589.799988
# Name: High, Length: 1356, dtype: string

# %% [markdown]
# 7. А теперь найдите в этом столбце строки, которые содержат цифру 4, но не содержат цифру 8.

# %%
df[(df.str.contains("4") == True) & (df.str.contains("8") == False)]
# Out:
# 1            30.42
# 22       20.440001
# 26       21.549999
# 34            19.4
# 46           21.24
#            ...
# 2397    471.630005
# 2402    547.409973
# 2404    514.460022
# 2407         594.5
# 2410    564.440002
# Name: High, Length: 636, dtype: string

# %% [markdown]
# 8. И наконец найдите в столбце Hihg (пусть там все еще будет строковый тип) такие строчки, у которых в дробной части есть цифра 3 и замените ее на 4.
# Подсказка: может помочь метод split.
# А потом замените эти значения в датафрейме на какое-нибудь слово. Например, лопата.

# %% [markdown]
# Шложна

# %% [markdown]
# 9. Нормализовать столбец Open

# %%
df = pd.read_csv('data/TSLA.csv');

# %%
df.Open.apply(lambda x: (x-df.Open.min())/(df.Open.max()-df.Open.min()))
# Out:
# 0       0.004349
# 1       0.014676
# 2       0.013474
# 3       0.010433
# 4       0.005870
#           ...
# 2411    0.840012
# 2412    0.850962
# 2413    0.937237
# 2414    0.948764
# 2415    1.000000
# Name: Open, Length: 2416, dtype: float64

# %% [markdown]
# 10. И, правда наконец, создайте пустой датафрейм с такими же колонками, как TSLA. Пусть в нем будет 10 строк. И пусть они будут заполнены такими значениями: в i-й строке j-го столбца должна быть j-ая степень числа i+j. Добавьте этот датафрейм в конец исходного.
# Используйте метод tail, чтобы увидеть конец полученного датафрейма и порадоваться, что у вас все получилось и вы готовы реально обрабатывать датафреймы и заниматься дата сасом.

# %%
me = pd.DataFrame()
for i in range (0, 10):
    for j in range (0, 7):
        me.loc[i, j] = (i+j)**j
me
# Out:
#      0     1      2       3        4         5           6
# 0  1.0   1.0    4.0    27.0    256.0    3125.0     46656.0
# 1  1.0   2.0    9.0    64.0    625.0    7776.0    117649.0
# 2  1.0   3.0   16.0   125.0   1296.0   16807.0    262144.0
# 3  1.0   4.0   25.0   216.0   2401.0   32768.0    531441.0
# 4  1.0   5.0   36.0   343.0   4096.0   59049.0   1000000.0
# 5  1.0   6.0   49.0   512.0   6561.0  100000.0   1771561.0
# 6  1.0   7.0   64.0   729.0  10000.0  161051.0   2985984.0
# 7  1.0   8.0   81.0  1000.0  14641.0  248832.0   4826809.0
# 8  1.0   9.0  100.0  1331.0  20736.0  371293.0   7529536.0
# 9  1.0  10.0  121.0  1728.0  28561.0  537824.0  11390625.0

# %%
me.rename(columns = {0: 'Date', 1: 'Open', 2: 'High', 3: 'Low', 4: 'Close', 5: 'Adj Close', 6: 'Volume'}, inplace = True)
me
# Out:
#    Date  Open   High     Low    Close  Adj Close      Volume
# 0   1.0   1.0    4.0    27.0    256.0     3125.0     46656.0
# 1   1.0   2.0    9.0    64.0    625.0     7776.0    117649.0
# 2   1.0   3.0   16.0   125.0   1296.0    16807.0    262144.0
# 3   1.0   4.0   25.0   216.0   2401.0    32768.0    531441.0
# 4   1.0   5.0   36.0   343.0   4096.0    59049.0   1000000.0
# 5   1.0   6.0   49.0   512.0   6561.0   100000.0   1771561.0
# 6   1.0   7.0   64.0   729.0  10000.0   161051.0   2985984.0
# 7   1.0   8.0   81.0  1000.0  14641.0   248832.0   4826809.0
# 8   1.0   9.0  100.0  1331.0  20736.0   371293.0   7529536.0
# 9   1.0  10.0  121.0  1728.0  28561.0   537824.0  11390625.0

# %%
df.append(me)
# Out:
#           Date       Open    High          Low         Close      Adj Close  \
# 0   2010-06-29  19.000000   25.00    17.540001     23.889999      23.889999
# 1   2010-06-30  25.790001   30.42    23.299999     23.830000      23.830000
# 2   2010-07-01  25.000000   25.92    20.270000     21.959999      21.959999
# 3   2010-07-02  23.000000   23.10    18.709999     19.200001      19.200001
# 4   2010-07-06  20.000000   20.00    15.830000     16.110001      16.110001
# ..         ...        ...     ...          ...           ...            ...
# 5          1.0   6.000000   49.00   512.000000   6561.000000  100000.000000
# 6          1.0   7.000000   64.00   729.000000  10000.000000  161051.000000
# 7          1.0   8.000000   81.00  1000.000000  14641.000000  248832.000000
# 8          1.0   9.000000  100.00  1331.000000  20736.000000  371293.000000
# 9          1.0  10.000000  121.00  1728.000000  28561.000000  537824.000000
#
#         Volume
# 0   18766300.0
# 1   17187100.0
# 2    8218800.0
# 3    5139800.0
# 4    6866900.0
# ..         ...
# 5    1771561.0
# 6    2985984.0
# 7    4826809.0
# 8    7529536.0
# 9   11390625.0
#
# [2426 rows x 7 columns]
